# %%
bt = get_backtest('5ec1fb6091cc1a46b1b62609')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:10|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-06-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2016-06-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.465%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>8.535%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>16.352%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.58</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.54</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
# ...
